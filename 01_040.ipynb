# %%
# !ls

# %%
# !cat /proc/cpuinfo

# %%
# !cat /proc/meminfo

# %% [markdown]
# #Section 1
# A section command in **text** code format creates a seperate category of code like a *sub-code*, so that all the cells of code that are excecuted after that section comes under it. Basically helps in organisation of code, makes it look less cramped.

# %%
# !ls
# Out:
# sample_data

# %%
# !cat /proc/meminfo

# %% [markdown]
# This is a text cell for reference, **Latex** can also be used here for example $\LaTeX$. **Shift+enter** for the excecution of **text** code and **Clt+enter** for the excecution of **normal** code.
